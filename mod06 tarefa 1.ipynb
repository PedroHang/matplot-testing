# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
sinasc = pd.read_csv('SINASC_RO_2019.csv')
sinasc.drop_duplicates().shape
df = pd.DataFrame(sinasc)
df
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0           1  2679477.0      110001        1        19        5.0
# 1           1  2679477.0      110001        1        29        2.0
# 2           1  2679477.0      110001        1        37        9.0
# 3           1  2516500.0      110001        1        30        5.0
# 4           1  2516500.0      110001        1        30        2.0
# ...       ...        ...         ...      ...       ...        ...
# 27023       1  2604388.0      510340        1        32        2.0
# 27024       1  2752654.0      510675        1        19        1.0
# 27025       1  9659366.0      510787        1        24        2.0
# 27026       1  9659366.0      510787        1        21        2.0
# 27027       1  2795655.0      510792        1        18        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0          8 a 11 anos         NaN         0.0         0.0  ...           5
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
fig1 = plt.figure()
fig1.suptitle('APGAR 1')   
counts1 = df['APGAR1'].value_counts()
ax1 = fig1.add_subplot(1,1,1)
plt.bar(counts1.index, counts1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 11 artists>

# %%
fig2 = plt.figure()
fig2.suptitle('APGAR 5')   
counts2 = df['APGAR5'].value_counts()
ax2 = fig2.add_subplot(1,1,1)
plt.bar(counts2.index, counts2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 11 artists>

# %%
fig3 = plt.figure()
fig3.suptitle('SEXO')   
counts3 = df['SEXO'].value_counts()
ax3 = fig3.add_subplot(1,1,1)
plt.bar(counts3.index, counts3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 2 artists>

# %%
fig4 = plt.figure()
fig4.suptitle('GESTACAO')   
counts4 = df['GESTACAO'].value_counts()
ax4 = fig4.add_subplot(1,1,1)

plt.xticks(rotation=90)
plt.subplots_adjust(bottom=0.3)
plt.bar(counts4.index, counts4)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 6 artists>

# %%
fig5 = plt.figure()
fig5.suptitle('ESTCIVMAE')   
counts5 = df['ESTCIVMAE'].value_counts()
ax5 = fig5.add_subplot(1,1,1)


plt.bar(counts5.index, counts5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 6 artists>

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
fig6 = plt.figure()
fig6.suptitle('APGAR 5 MÉDIO CONFORME NÚMERO DE CONSULTAS PRÉ-NATAL:') 
pre_filtered1 = df.loc[df['CONSULTAS'] == 1, 'APGAR5']
filtered1 = pre_filtered1.mean()

pre_filtered2 = df.loc[df['CONSULTAS'] == 2, 'APGAR5']
filtered2 = pre_filtered2.mean()

averages = [filtered1, filtered2]
labels = ['0 Consultas', '1 a 3 Consultas']
colors = ['red', 'blue']

ax6 = fig6.add_subplot(1,1,1)
plt.bar(labels, averages, color=colors)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 2 artists>

# %% [markdown]
# <h3>Nota-se pouca correlação entre o número de consultas e o valor APGAR 5 ao nascer</h3>
# <h4> No entanto não podemos desconsiderar os benefícios de consultas pré-natais para o desenvolvimento saudável
# da criança.</h4>

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
fig7 = plt.figure()
fig7.suptitle('Frequências')   

counts_sexo = df['SEXO'].value_counts()
counts_gestacao = df['GESTACAO'].value_counts()
counts_estcivmae = df['ESTCIVMAE'].value_counts()
counts_consultas = df['CONSULTAS'].value_counts()

ax_sexo = fig7.add_subplot(2,2,1)
plt.bar(counts_sexo.index, counts_sexo, color='red')

ax_gestacao = fig7.add_subplot(2,2,2)
plt.bar(counts_gestacao.index, counts_gestacao)

ax_estcivmae = fig7.add_subplot(2,2,3)
plt.bar(counts_estcivmae.index, counts_estcivmae, color='green')

ax_consultas = fig7.add_subplot(2,2,4)
plt.bar(counts_consultas.index, counts_consultas, color='purple')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>
